# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
# Load data WeatherPy_vacation.csv into dataframe
vacation_data_df = pd.read_csv("Vacation_Search/WeatherPy_vacation.csv")
vacation_data_df.head(10)
# Out:
#          City Country  Max Temp Current Description      Lat       Lng  \
# 0        Abay      KZ     39.58    scattered clouds  49.6311   72.8539
# 1       Abnūb      EG     75.54          few clouds  27.2696   31.1511
# 2  Abu Samrah      SY     66.25           clear sky  35.3029   37.1841
# 3      Acaraú      BR     77.83    scattered clouds  -2.8856  -40.1200
# 4         Ada      US     76.35           clear sky  43.4166 -116.1262
# 5  Santa Cruz      MA     66.65    scattered clouds  30.4202   -9.5982
# 6    Agropoli      IT     70.29          few clouds  40.3469   14.9966
# 7     Ahipara      NZ     61.75          light rain -35.1667  173.1667
# 8       Airai      TL     59.95    scattered clouds  -8.9266  125.4092
# 9     Aklavik      CA     51.17          few clouds  68.2191 -135.0107
#
#                  Hotel Name
# 0  Guest House on Abaya 144
# 1           Romany Adly Gad
# 2                       NaN
# 3          castelo pizzaria
# 4                       NaN
# 5    Iberostar Founty Beach
# 6      B&B Baia di Trentova
# 7      Ahipara Holiday Park
# 8            Juvinal Martin
# 9               Aklavik Inn

# %%
# Find all cities count in the same country
vacation_data_df["Country"].value_counts().head()
# Out:
# RU    85
# AU    34
# BR    30
# CN    25
# ID    22
# Name: Country, dtype: int64

# %%
#Select country Brazil dataframe
travel_by_car_df = vacation_data_df.loc[vacation_data_df["Country"] == "BR"]
travel_by_car_df
# Out:
#                   City Country  Max Temp Current Description      Lat  \
# 3               Acaraú      BR     77.83    scattered clouds  -2.8856
# 15       Alta Floresta      BR     76.93       broken clouds  -9.8756
# 18               Amapá      BR     72.54          light rain   1.0000
# 29     Arraial do Cabo      BR     73.36       broken clouds -22.9661
# 67        Boca do Acre      BR     74.88     overcast clouds  -8.7522
# 69           Bom Jesus      BR     78.35     overcast clouds  -9.0744
# 95          Carutapera      BR     74.80       moderate rain  -1.1950
# 96         Cassilândia      BR     74.53    scattered clouds -19.1133
# 97              Castro      BR     60.35     overcast clouds -24.7911
# 106           Cidreira      BR     63.05          light rain -30.1811
# 143              Gália      BR     72.59    scattered clouds -22.2914
# 158          Guarapari      BR     72.90     overcast clouds -20.6667
# 187              Igaci      BR     68.74           clear sky  -9.5369
# 189           Ilhabela      BR     69.53    scattered clouds -23.7781
# 193            Ipameri      BR     71.98     overcast clouds -17.7219
# 198            Itarema      BR     77.40    scattered clouds  -2.9248
# 202       Jacareacanga      BR     78.80     overcast clouds  -6.2222
# 284           Maragogi      BR     75.79           clear sky  -9.0122
# 287            Marília      BR     67.17    scattered clouds -22.2139
# 319           Nhamundá      BR     79.99     overcast clouds  -2.1861
# 347            Penalva      BR     79.36       broken clouds  -3.2942
# 357  Plácido de Castro      BR     79.59     overcast clouds -10.3353
# 392          Rio Claro      BR     65.80       broken clouds -22.4114
# 413           Santarém      BR     78.93           clear sky  -2.4431
# 414           São João      BR     64.33          few clouds  -8.8756
# 415  São João da Barra      BR     74.34       moderate rain -21.6403
# 436           Soledade      BR     52.75     overcast clouds -28.8183
# 471             Trairi      BR     77.27          few clouds  -3.2778
# 474           Trindade      BR     74.32     overcast clouds -16.6494
# 502         Vila Velha      BR     73.35           clear sky -20.3297
#
#          Lng                                Hotel Name
# 3   -40.1200                          castelo pizzaria
# 15  -56.0861                  Floresta Amazonica Hotel
# 18  -52.0000                                       NaN
# 29  -42.0278                       Pousada Porto Praia
# 67  -67.3978                           Hotel Sao Pedro
# 69  -44.3586    Hotel Brasão & Floricultura Bella Flor
# 95  -46.0200                                    Lidera
# 96  -51.7342                            Delirius Motel
# 97  -50.0119                            CHACARA BAILLY
# 106 -50.2056                             Hotel Castelo
# 143 -49.5528                               Galia Hotel
# 158 -40.4975                        Hotel Porto do Sol
# 187 -36.6336                                  JE Hotel
# 189 -45.3581                           Ilha Flat Hotel
# 193 -48.1597                                Real Hotel
# 198 -39.9167        Sea Lounge! Bar, Club & Restaurant
# 202 -57.7528                              Casa do Ian😎
# 284 -35.2225  Salinas do Maragogi All Inclusive Resort
# 287 -49.9458                               Hotel Tenda
# 319 -56.7131                          Pousada Da Praia
# 347 -45.1736                            Hotel São José
# 357 -67.1856                             Hotel Carioca
# 392 -47.5614     Hotel Vivendas Rio Claro by Atlantica
# 413 -54.7083                              Ecotur Lodge
# 414 -36.3667                      Chácara Mãe Natureza
# 415 -41.0511                   Pousada Porto De Canoas
# 436 -52.5103                         Pousada Da Gringa
# 471 -39.2689                            janelas do mar
# 474 -49.4889                           Pousada Central
# 502 -40.2925                 Quality Suites Vila Velha

# %%
#please the trip by car over four cities
# use index to select the cities in order
travel_by_car_df = travel_by_car_df.loc[[96,193,284,198]]
travel_by_car_df
# Out:
#             City Country  Max Temp Current Description      Lat      Lng  \
# 96   Cassilândia      BR     74.53    scattered clouds -19.1133 -51.7342
# 193      Ipameri      BR     71.98     overcast clouds -17.7219 -48.1597
# 284     Maragogi      BR     75.79           clear sky  -9.0122 -35.2225
# 198      Itarema      BR     77.40    scattered clouds  -2.9248 -39.9167
#
#                                    Hotel Name
# 96                             Delirius Motel
# 193                                Real Hotel
# 284  Salinas do Maragogi All Inclusive Resort
# 198        Sea Lounge! Bar, Club & Restaurant

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
#Create the tuple list of lat and lng for travel
trip_plan = [ (row["Lat"],row["Lng"]) for _,row in travel_by_car_df.iterrows()]
trip_plan
# Out:
# [(-19.1133, -51.7342),
#  (-17.7219, -48.1597),
#  (-9.0122, -35.2225),
#  (-2.9248, -39.9167)]

# %%
# get the gmaps figure
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# create a direction layer
direction_layer = gmaps.directions_layer(trip_plan[0],trip_plan[-1],waypoints=trip_plan[1:-1],travel_mode='DRIVING')
# add the direction layers in the gmaps figure
fig.add_layer(direction_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#info box template that pop-screen when mouse-click
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""

# %%
# Store the hotel box info in list.
hotel_info = [info_box_template.format(**row) for index, row in travel_by_car_df.iterrows()]

# %%
# Add the vacation spots and a pop-up marker for each city.
#locations = travel_by_car_df[["Lat", "Lng"]]
# get the gmaps figure
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)

# Create a marker layer
marker_layer = gmaps.marker_layer(trip_plan, info_box_content=hotel_info)

# add marker and direction layers in the gmaps figure
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
