# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# import the requests module
import requests
# Import the datetime module from the datetime library.
from datetime import datetime
# Import the API key.
from config import weather_api_key
# Import the time module.
import time
# Import scipy.stat 
from scipy.stats import linregress
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-e29d2098b632> in <module>
#       9 from datetime import datetime
#      10 # Import the API key.
# ---> 11 from config import weather_api_key
#      12 # Import the time module.
#      13 import time
#
# ModuleNotFoundError: No module named 'config'

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 610

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i,city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
len(city_data)
# Out:
# Processing Record 1 of Set 1 | saskylakh
# Processing Record 2 of Set 1 | puerto carreno
# Processing Record 3 of Set 1 | tiksi
# Processing Record 4 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 1 | sangar
# Processing Record 6 of Set 1 | faanui
# Processing Record 7 of Set 1 | bredasdorp
# Processing Record 8 of Set 1 | fortuna
# Processing Record 9 of Set 1 | ugep
# Processing Record 10 of Set 1 | lagoa
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | yellowknife
# Processing Record 13 of Set 1 | pangnirtung
# Processing Record 14 of Set 1 | cabo san lucas
# Processing Record 15 of Set 1 | qaanaaq
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | grindavik
# Processing Record 18 of Set 1 | cape town
# Processing Record 19 of Set 1 | sitka
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | kamiiso
# Processing Record 22 of Set 1 | henties bay
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | korla
# Processing Record 26 of Set 1 | sibu
# Processing Record 27 of Set 1 | osoyoos
# Processing Record 28 of Set 1 | dikson
# Processing Record 29 of Set 1 | ponta do sol
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | nikolskoye
# Processing Record 32 of Set 1 | ancud
# Processing Record 33 of Set 1 | bilma
# Processing Record 34 of Set 1 | luau
# Processing Record 35 of Set 1 | chokurdakh
# Processing Record 36 of Set 1 | hilo
# Processing Record 37 of Set 1 | alice springs
# Processing Record 38 of Set 1 | bolanos de calatrava
# Processing Record 39 of Set 1 | mahebourg
# Processing Record 40 of Set 1 | hobart
# Processing Record 41 of Set 1 | coihaique
# Processing Record 42 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 1 | rikitea
# Processing Record 44 of Set 1 | omboue
# Processing Record 45 of Set 1 | provideniya
# Processing Record 46 of Set 1 | sakakah
# Processing Record 47 of Set 1 | bunia
# Processing Record 48 of Set 1 | burica
# City not found. Skipping...
# Processing Record 49 of Set 1 | victoria
# Processing Record 50 of Set 1 | baturite
# Processing Record 1 of Set 2 | oriximina
# Processing Record 2 of Set 2 | thompson
# Processing Record 3 of Set 2 | hangu
# Processing Record 4 of Set 2 | tuktoyaktuk
# Processing Record 5 of Set 2 | georgetown
# Processing Record 6 of Set 2 | astana
# Processing Record 7 of Set 2 | yuryevets
# Processing Record 8 of Set 2 | pevek
# Processing Record 9 of Set 2 | maceio
# Processing Record 10 of Set 2 | sayyan
# Processing Record 11 of Set 2 | ambanja
# Processing Record 12 of Set 2 | victor harbor
# Processing Record 13 of Set 2 | atuona
# Processing Record 14 of Set 2 | kaitangata
# Processing Record 15 of Set 2 | danielskuil
# Processing Record 16 of Set 2 | hermanus
# Processing Record 17 of Set 2 | ko samui
# Processing Record 18 of Set 2 | vaini
# Processing Record 19 of Set 2 | port lincoln
# Processing Record 20 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 2 | aksarka
# Processing Record 22 of Set 2 | namatanai
# Processing Record 23 of Set 2 | avarua
# Processing Record 24 of Set 2 | agropoli
# Processing Record 25 of Set 2 | carnarvon
# Processing Record 26 of Set 2 | geraldton
# Processing Record 27 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 28 of Set 2 | vinh yen
# Processing Record 29 of Set 2 | jamestown
# Processing Record 30 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 2 | hemnesberget
# Processing Record 32 of Set 2 | ribeira grande
# Processing Record 33 of Set 2 | new norfolk
# Processing Record 34 of Set 2 | flinders
# Processing Record 35 of Set 2 | laguna
# Processing Record 36 of Set 2 | jizan
# Processing Record 37 of Set 2 | gobabis
# Processing Record 38 of Set 2 | butaritari
# Processing Record 39 of Set 2 | barillas
# Processing Record 40 of Set 2 | tasiilaq
# Processing Record 41 of Set 2 | ukiah
# Processing Record 42 of Set 2 | maraa
# Processing Record 43 of Set 2 | belaya
# Processing Record 44 of Set 2 | hami
# Processing Record 45 of Set 2 | olinda
# Processing Record 46 of Set 2 | lebu
# Processing Record 47 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 2 | anadyr
# Processing Record 49 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 2 | ambodifototra
# City not found. Skipping...
# Processing Record 1 of Set 3 | barrow
# Processing Record 2 of Set 3 | kushima
# Processing Record 3 of Set 3 | timizart
# Processing Record 4 of Set 3 | berdigestyakh
# Processing Record 5 of Set 3 | kavalerovo
# Processing Record 6 of Set 3 | tromso
# Processing Record 7 of Set 3 | the valley
# Processing Record 8 of Set 3 | villarrubia de los ojos
# Processing Record 9 of Set 3 | nanortalik
# Processing Record 10 of Set 3 | mareeba
# Processing Record 11 of Set 3 | bethel
# Processing Record 12 of Set 3 | puerto escondido
# Processing Record 13 of Set 3 | elhovo
# Processing Record 14 of Set 3 | makat
# Processing Record 15 of Set 3 | cabedelo
# Processing Record 16 of Set 3 | parrita
# Processing Record 17 of Set 3 | taoudenni
# Processing Record 18 of Set 3 | otane
# Processing Record 19 of Set 3 | port alfred
# Processing Record 20 of Set 3 | tautira
# Processing Record 21 of Set 3 | bagdarin
# Processing Record 22 of Set 3 | dingle
# Processing Record 23 of Set 3 | yulara
# Processing Record 24 of Set 3 | marrakesh
# Processing Record 25 of Set 3 | faya
# Processing Record 26 of Set 3 | baykit
# Processing Record 27 of Set 3 | esperance
# Processing Record 28 of Set 3 | fuyang
# Processing Record 29 of Set 3 | mar del plata
# Processing Record 30 of Set 3 | bengkulu
# Processing Record 31 of Set 3 | yar-sale
# Processing Record 32 of Set 3 | castro
# Processing Record 33 of Set 3 | arman
# Processing Record 34 of Set 3 | safita
# Processing Record 35 of Set 3 | hasaki
# Processing Record 36 of Set 3 | bluff
# Processing Record 37 of Set 3 | pisco
# Processing Record 38 of Set 3 | hithadhoo
# Processing Record 39 of Set 3 | teeli
# Processing Record 40 of Set 3 | yumen
# Processing Record 41 of Set 3 | sakyla
# Processing Record 42 of Set 3 | saint-philippe
# Processing Record 43 of Set 3 | saint-augustin
# Processing Record 44 of Set 3 | kangaatsiaq
# Processing Record 45 of Set 3 | shimoda
# Processing Record 46 of Set 3 | sabha
# Processing Record 47 of Set 3 | gigmoto
# Processing Record 48 of Set 3 | mpigi
# Processing Record 49 of Set 3 | ostrovnoy
# Processing Record 50 of Set 3 | chuy
# Processing Record 1 of Set 4 | nome
# Processing Record 2 of Set 4 | poum
# Processing Record 3 of Set 4 | ozernovskiy
# Processing Record 4 of Set 4 | montecristi
# Processing Record 5 of Set 4 | puerto ayora
# Processing Record 6 of Set 4 | sakaiminato
# Processing Record 7 of Set 4 | talnakh
# Processing Record 8 of Set 4 | airai
# Processing Record 9 of Set 4 | monastyrshchina
# Processing Record 10 of Set 4 | kenai
# Processing Record 11 of Set 4 | arandelovac
# City not found. Skipping...
# Processing Record 12 of Set 4 | khatanga
# Processing Record 13 of Set 4 | vorotynsk
# Processing Record 14 of Set 4 | san patricio
# Processing Record 15 of Set 4 | portland
# Processing Record 16 of Set 4 | cartagena
# Processing Record 17 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 18 of Set 4 | hamilton
# Processing Record 19 of Set 4 | padang
# Processing Record 20 of Set 4 | yerbogachen
# Processing Record 21 of Set 4 | kaeo
# Processing Record 22 of Set 4 | klaksvik
# Processing Record 23 of Set 4 | cody
# Processing Record 24 of Set 4 | shiyan
# Processing Record 25 of Set 4 | kalmunai
# Processing Record 26 of Set 4 | coahuayana
# Processing Record 27 of Set 4 | myanaung
# Processing Record 28 of Set 4 | kegayli
# City not found. Skipping...
# Processing Record 29 of Set 4 | port blair
# Processing Record 30 of Set 4 | kenora
# Processing Record 31 of Set 4 | lethem
# Processing Record 32 of Set 4 | bocaiuva
# Processing Record 33 of Set 4 | umm durman
# City not found. Skipping...
# Processing Record 34 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 4 | sayan
# Processing Record 36 of Set 4 | coquimbo
# Processing Record 37 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 4 | hovd
# Processing Record 39 of Set 4 | iqaluit
# Processing Record 40 of Set 4 | half moon bay
# Processing Record 41 of Set 4 | nabire
# Processing Record 42 of Set 4 | los llanos de aridane
# Processing Record 43 of Set 4 | berlevag
# Processing Record 44 of Set 4 | tessalit
# Processing Record 45 of Set 4 | mecca
# Processing Record 46 of Set 4 | urucui
# Processing Record 47 of Set 4 | tual
# Processing Record 48 of Set 4 | asau
# Processing Record 49 of Set 4 | luanda
# Processing Record 50 of Set 4 | lorengau
# Processing Record 1 of Set 5 | kant
# Processing Record 2 of Set 5 | tunduru
# City not found. Skipping...
# Processing Record 3 of Set 5 | pangody
# Processing Record 4 of Set 5 | volkhovskiy
# Processing Record 5 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 6 of Set 5 | corinto
# Processing Record 7 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 5 | margate
# Processing Record 9 of Set 5 | constitucion
# Processing Record 10 of Set 5 | ulaangom
# Processing Record 11 of Set 5 | galegos
# Processing Record 12 of Set 5 | kodinsk
# Processing Record 13 of Set 5 | marzuq
# Processing Record 14 of Set 5 | guerrero negro
# Processing Record 15 of Set 5 | altoona
# Processing Record 16 of Set 5 | ketchikan
# Processing Record 17 of Set 5 | bandarbeyla
# Processing Record 18 of Set 5 | leningradskiy
# Processing Record 19 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 5 | norman wells
# Processing Record 21 of Set 5 | acapulco
# Processing Record 22 of Set 5 | tiznit
# Processing Record 23 of Set 5 | adrar
# Processing Record 24 of Set 5 | namibe
# Processing Record 25 of Set 5 | caucaia
# Processing Record 26 of Set 5 | komsomolskiy
# Processing Record 27 of Set 5 | fevralsk
# City not found. Skipping...
# Processing Record 28 of Set 5 | skibbereen
# Processing Record 29 of Set 5 | nazare da mata
# Processing Record 30 of Set 5 | torbay
# Processing Record 31 of Set 5 | tigre
# Processing Record 32 of Set 5 | wasco
# Processing Record 33 of Set 5 | sao jose da coroa grande
# Processing Record 34 of Set 5 | saint-joseph
# Processing Record 35 of Set 5 | axim
# Processing Record 36 of Set 5 | severo-kurilsk
# Processing Record 37 of Set 5 | panjwin
# City not found. Skipping...
# Processing Record 38 of Set 5 | baruun-urt
# Processing Record 39 of Set 5 | bogande
# Processing Record 40 of Set 5 | loandjili
# Processing Record 41 of Set 5 | auki
# Processing Record 42 of Set 5 | chapais
# Processing Record 43 of Set 5 | maragogi
# Processing Record 44 of Set 5 | panzhihua
# Processing Record 45 of Set 5 | san angelo
# Processing Record 46 of Set 5 | chapadinha
# Processing Record 47 of Set 5 | bonavista
# Processing Record 48 of Set 5 | binzhou
# Processing Record 49 of Set 5 | bambous virieux
# Processing Record 50 of Set 5 | port elizabeth
# Processing Record 1 of Set 6 | naze
# Processing Record 2 of Set 6 | egvekinot
# Processing Record 3 of Set 6 | jamiltepec
# Processing Record 4 of Set 6 | machico
# Processing Record 5 of Set 6 | rocha
# Processing Record 6 of Set 6 | vicar
# Processing Record 7 of Set 6 | novyy urgal
# Processing Record 8 of Set 6 | mosquera
# Processing Record 9 of Set 6 | stephenville
# Processing Record 10 of Set 6 | saint-paul
# Processing Record 11 of Set 6 | lavrentiya
# Processing Record 12 of Set 6 | zyryanka
# Processing Record 13 of Set 6 | rzhev
# Processing Record 14 of Set 6 | manicore
# Processing Record 15 of Set 6 | kingman
# Processing Record 16 of Set 6 | dabakala
# Processing Record 17 of Set 6 | brekstad
# Processing Record 18 of Set 6 | safwah
# City not found. Skipping...
# Processing Record 19 of Set 6 | rawson
# Processing Record 20 of Set 6 | broome
# Processing Record 21 of Set 6 | luderitz
# Processing Record 22 of Set 6 | toamasina
# Processing Record 23 of Set 6 | inhambane
# Processing Record 24 of Set 6 | labuan
# Processing Record 25 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 6 | tabas
# Processing Record 27 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set 6 | lata
# Processing Record 29 of Set 6 | chernyshevskiy
# Processing Record 30 of Set 6 | sobolevo
# Processing Record 31 of Set 6 | matay
# Processing Record 32 of Set 6 | narsaq
# Processing Record 33 of Set 6 | novikovo
# Processing Record 34 of Set 6 | deputatskiy
# Processing Record 35 of Set 6 | leh
# Processing Record 36 of Set 6 | northam
# Processing Record 37 of Set 6 | chicama
# Processing Record 38 of Set 6 | coolum beach
# Processing Record 39 of Set 6 | erzin
# Processing Record 40 of Set 6 | kachiry
# Processing Record 41 of Set 6 | huanren
# Processing Record 42 of Set 6 | nuuk
# Processing Record 43 of Set 6 | arraial do cabo
# Processing Record 44 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 6 | east london
# Processing Record 46 of Set 6 | rio gallegos
# Processing Record 47 of Set 6 | santa cruz
# Processing Record 48 of Set 6 | aranda
# Processing Record 49 of Set 6 | codrington
# Processing Record 50 of Set 6 | avera
# Processing Record 1 of Set 7 | banda aceh
# Processing Record 2 of Set 7 | abilene
# Processing Record 3 of Set 7 | fairbanks
# Processing Record 4 of Set 7 | bako
# Processing Record 5 of Set 7 | swift current
# Processing Record 6 of Set 7 | tres arroyos
# Processing Record 7 of Set 7 | eureka
# Processing Record 8 of Set 7 | dzilam gonzalez
# Processing Record 9 of Set 7 | vila franca do campo
# Processing Record 10 of Set 7 | bintulu
# Processing Record 11 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 7 | katsuura
# Processing Record 13 of Set 7 | sao joao da barra
# Processing Record 14 of Set 7 | longyearbyen
# Processing Record 15 of Set 7 | mount hagen
# Processing Record 16 of Set 7 | pokaran
# Processing Record 17 of Set 7 | bardiyah
# Processing Record 18 of Set 7 | hualmay
# Processing Record 19 of Set 7 | susanville
# Processing Record 20 of Set 7 | nemuro
# Processing Record 21 of Set 7 | sorland
# Processing Record 22 of Set 7 | pemangkat
# Processing Record 23 of Set 7 | hambantota
# Processing Record 24 of Set 7 | buta
# Processing Record 25 of Set 7 | weinan
# Processing Record 26 of Set 7 | ozuluama
# Processing Record 27 of Set 7 | saint anthony
# Processing Record 28 of Set 7 | patacamaya
# Processing Record 29 of Set 7 | port shepstone
# Processing Record 30 of Set 7 | beringovskiy
# Processing Record 31 of Set 7 | cherskiy
# Processing Record 32 of Set 7 | kapenguria
# Processing Record 33 of Set 7 | borogontsy
# Processing Record 34 of Set 7 | eydhafushi
# Processing Record 35 of Set 7 | ye
# City not found. Skipping...
# Processing Record 36 of Set 7 | cumra
# Processing Record 37 of Set 7 | jasper
# Processing Record 38 of Set 7 | sao gabriel da cachoeira
# Processing Record 39 of Set 7 | pietarsaari
# Processing Record 40 of Set 7 | ugoofaaru
# Processing Record 41 of Set 7 | dzaoudzi
# Processing Record 42 of Set 7 | kodiak
# Processing Record 43 of Set 7 | owosso
# Processing Record 44 of Set 7 | kourou
# Processing Record 45 of Set 7 | aska
# Processing Record 46 of Set 7 | sagua la grande
# Processing Record 47 of Set 7 | gamba
# Processing Record 48 of Set 7 | gaya
# Processing Record 49 of Set 7 | salina cruz
# Processing Record 50 of Set 7 | harrison
# Processing Record 1 of Set 8 | liminangcong
# City not found. Skipping...
# Processing Record 2 of Set 8 | brae
# Processing Record 3 of Set 8 | upernavik
# Processing Record 4 of Set 8 | haapu
# City not found. Skipping...
# Processing Record 5 of Set 8 | umm kaddadah
# Processing Record 6 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 8 | port moresby
# Processing Record 8 of Set 8 | nampula
# Processing Record 9 of Set 8 | angra
# City not found. Skipping...
# Processing Record 10 of Set 8 | tsienyane
# City not found. Skipping...
# Processing Record 11 of Set 8 | la ronge
# Processing Record 12 of Set 8 | ilulissat
# Processing Record 13 of Set 8 | moerai
# Processing Record 14 of Set 8 | marawi
# Processing Record 15 of Set 8 | chengdu
# Processing Record 16 of Set 8 | nhulunbuy
# Processing Record 17 of Set 8 | winnemucca
# Processing Record 18 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 19 of Set 8 | muroto
# Processing Record 20 of Set 8 | westport
# Processing Record 21 of Set 8 | buluang
# Processing Record 22 of Set 8 | havelock
# Processing Record 23 of Set 8 | bathsheba
# Processing Record 24 of Set 8 | alvaraes
# Processing Record 25 of Set 8 | salisbury
# Processing Record 26 of Set 8 | iraray
# Processing Record 27 of Set 8 | uvira
# Processing Record 28 of Set 8 | honiara
# Processing Record 29 of Set 8 | cockburn town
# Processing Record 30 of Set 8 | cortland
# Processing Record 31 of Set 8 | kirakira
# Processing Record 32 of Set 8 | kavieng
# Processing Record 33 of Set 8 | kavaratti
# Processing Record 34 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 8 | kapuskasing
# Processing Record 36 of Set 8 | bolu
# Processing Record 37 of Set 8 | vanavara
# Processing Record 38 of Set 8 | champasak
# Processing Record 39 of Set 8 | murgab
# Processing Record 40 of Set 8 | quesnel
# Processing Record 41 of Set 8 | meulaboh
# Processing Record 42 of Set 8 | colares
# Processing Record 43 of Set 8 | srednekolymsk
# Processing Record 44 of Set 8 | port-gentil
# Processing Record 45 of Set 8 | lompoc
# Processing Record 46 of Set 8 | lagos
# Processing Record 47 of Set 8 | gladstone
# Processing Record 48 of Set 8 | saldanha
# Processing Record 49 of Set 8 | baft
# Processing Record 50 of Set 8 | makurdi
# Processing Record 1 of Set 9 | poronaysk
# Processing Record 2 of Set 9 | sao filipe
# Processing Record 3 of Set 9 | khandyga
# Processing Record 4 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 5 of Set 9 | comodoro rivadavia
# Processing Record 6 of Set 9 | berger
# Processing Record 7 of Set 9 | sinnamary
# Processing Record 8 of Set 9 | coatzintla
# Processing Record 9 of Set 9 | aberdeen
# Processing Record 10 of Set 9 | ilula
# Processing Record 11 of Set 9 | awjilah
# Processing Record 12 of Set 9 | wells
# Processing Record 13 of Set 9 | sofiysk
# City not found. Skipping...
# Processing Record 14 of Set 9 | abiy adi
# City not found. Skipping...
# Processing Record 15 of Set 9 | yershov
# Processing Record 16 of Set 9 | santa maria
# Processing Record 17 of Set 9 | finschhafen
# Processing Record 18 of Set 9 | cay
# Processing Record 19 of Set 9 | sahuaripa
# Processing Record 20 of Set 9 | buala
# Processing Record 21 of Set 9 | irsha
# Processing Record 22 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 23 of Set 9 | hunchun
# Processing Record 24 of Set 9 | san quintin
# Processing Record 25 of Set 9 | pakdasht
# Processing Record 26 of Set 9 | te anau
# Processing Record 27 of Set 9 | oistins
# Processing Record 28 of Set 9 | kruisfontein
# Processing Record 29 of Set 9 | mocambique
# City not found. Skipping...
# Processing Record 30 of Set 9 | vammala
# Processing Record 31 of Set 9 | sampit
# Processing Record 32 of Set 9 | evensk
# Processing Record 33 of Set 9 | acari
# Processing Record 34 of Set 9 | carlagan
# Processing Record 35 of Set 9 | makokou
# Processing Record 36 of Set 9 | opuwo
# Processing Record 37 of Set 9 | aswan
# Processing Record 38 of Set 9 | michalovce
# Processing Record 39 of Set 9 | touros
# Processing Record 40 of Set 9 | ban nahin
# Processing Record 41 of Set 9 | kununurra
# Processing Record 42 of Set 9 | mana
# Processing Record 43 of Set 9 | bendigo
# Processing Record 44 of Set 9 | atasu
# Processing Record 45 of Set 9 | carupano
# Processing Record 46 of Set 9 | sistranda
# Processing Record 47 of Set 9 | atbasar
# Processing Record 48 of Set 9 | kismayo
# Processing Record 49 of Set 9 | nishihara
# Processing Record 50 of Set 9 | havoysund
# Processing Record 1 of Set 10 | kyzyl-suu
# Processing Record 2 of Set 10 | gulshat
# City not found. Skipping...
# Processing Record 3 of Set 10 | rindal
# Processing Record 4 of Set 10 | palmer
# Processing Record 5 of Set 10 | urumqi
# Processing Record 6 of Set 10 | viedma
# Processing Record 7 of Set 10 | ituporanga
# Processing Record 8 of Set 10 | nouadhibou
# Processing Record 9 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 10 | bambanglipuro
# Processing Record 11 of Set 10 | thinadhoo
# Processing Record 12 of Set 10 | harper
# Processing Record 13 of Set 10 | santa maria del oro
# Processing Record 14 of Set 10 | cabra
# Processing Record 15 of Set 10 | revin
# Processing Record 16 of Set 10 | barras
# Processing Record 17 of Set 10 | kulhudhuffushi
# Processing Record 18 of Set 10 | shingu
# Processing Record 19 of Set 10 | bowen
# Processing Record 20 of Set 10 | qeshm
# Processing Record 21 of Set 10 | kargasok
# Processing Record 22 of Set 10 | tazovskiy
# Processing Record 23 of Set 10 | san andres
# Processing Record 24 of Set 10 | karaton
# Processing Record 25 of Set 10 | mount gambier
# Processing Record 26 of Set 10 | sao felix do xingu
# Processing Record 27 of Set 10 | korem
# Processing Record 28 of Set 10 | opunake
# Processing Record 29 of Set 10 | valparaiso
# Processing Record 30 of Set 10 | carahue
# Processing Record 31 of Set 10 | tucurui
# Processing Record 32 of Set 10 | kinablangan
# Processing Record 33 of Set 10 | manokwari
# Processing Record 34 of Set 10 | saint george
# Processing Record 35 of Set 10 | gizo
# Processing Record 36 of Set 10 | olafsvik
# Processing Record 37 of Set 10 | vetlanda
# Processing Record 38 of Set 10 | popondetta
# Processing Record 39 of Set 10 | roald
# Processing Record 40 of Set 10 | mehamn
# Processing Record 41 of Set 10 | joao camara
# Processing Record 42 of Set 10 | coruripe
# Processing Record 43 of Set 10 | okhotsk
# Processing Record 44 of Set 10 | leua
# Processing Record 45 of Set 10 | neya
# Processing Record 46 of Set 10 | lanigan
# Processing Record 47 of Set 10 | petauke
# Processing Record 48 of Set 10 | teguise
# Processing Record 49 of Set 10 | gornopravdinsk
# Processing Record 50 of Set 10 | firminy
# Processing Record 1 of Set 11 | caravelas
# Processing Record 2 of Set 11 | toora-khem
# Processing Record 3 of Set 11 | vila
# Processing Record 4 of Set 11 | kurduvadi
# Processing Record 5 of Set 11 | hofn
# Processing Record 6 of Set 11 | shelburne
# Processing Record 7 of Set 11 | muros
# Processing Record 8 of Set 11 | terrace
# Processing Record 9 of Set 11 | vao
# Processing Record 10 of Set 11 | imbituba
# Processing Record 11 of Set 11 | clyde river
# Processing Record 12 of Set 11 | ucluelet
# Processing Record 13 of Set 11 | north bend
# Processing Record 14 of Set 11 | punta cardon
# Processing Record 15 of Set 11 | kinshasa
# Processing Record 16 of Set 11 | bac lieu
# Processing Record 17 of Set 11 | mazabuka
# Processing Record 18 of Set 11 | entre rios
# Processing Record 19 of Set 11 | sharjah
# Processing Record 20 of Set 11 | along
# Processing Record 21 of Set 11 | uruacu
# Processing Record 22 of Set 11 | kanker
# Processing Record 23 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 24 of Set 11 | qiongshan
# Processing Record 25 of Set 11 | vanimo
# Processing Record 26 of Set 11 | liverpool
# Processing Record 27 of Set 11 | juneau
# Processing Record 28 of Set 11 | sur
# Processing Record 29 of Set 11 | hit
# Processing Record 30 of Set 11 | gat
# Processing Record 31 of Set 11 | seljord
# Processing Record 32 of Set 11 | souillac
# Processing Record 33 of Set 11 | san juan
# Processing Record 34 of Set 11 | garowe
# Processing Record 35 of Set 11 | samarai
# Processing Record 36 of Set 11 | conway
# Processing Record 37 of Set 11 | tarakan
# Processing Record 38 of Set 11 | boatlaname
# City not found. Skipping...
# Processing Record 39 of Set 11 | babati
# Processing Record 40 of Set 11 | qandala
# Processing Record 41 of Set 11 | assiniboia
# Processing Record 42 of Set 11 | nalut
# Processing Record 43 of Set 11 | nizhniy odes
# Processing Record 44 of Set 11 | adre
# Processing Record 45 of Set 11 | betanzos
# Processing Record 46 of Set 11 | roma
# Processing Record 47 of Set 11 | tibiri
# Processing Record 48 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 49 of Set 11 | concordia
# Processing Record 50 of Set 11 | westerlo
# Processing Record 1 of Set 12 | rundu
# Processing Record 2 of Set 12 | tyukhtet
# Processing Record 3 of Set 12 | turangi
# Processing Record 4 of Set 12 | kapoeta
# Processing Record 5 of Set 12 | maniitsoq
# Processing Record 6 of Set 12 | mehran
# Processing Record 7 of Set 12 | jining
# Processing Record 8 of Set 12 | pakxan
# Processing Record 9 of Set 12 | tura
# Processing Record 10 of Set 12 | wejherowo
# Processing Record 11 of Set 12 | sicuani
# Processing Record 12 of Set 12 | carutapera
# Processing Record 13 of Set 12 | koslan
# Processing Record 14 of Set 12 | buariki
# City not found. Skipping...
# Processing Record 15 of Set 12 | hundested
# Processing Record 16 of Set 12 | pryozerne
# Processing Record 17 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 18 of Set 12 | biltine
# Processing Record 19 of Set 12 | akdepe
# Processing Record 20 of Set 12 | esil
# Processing Record 21 of Set 12 | aurich
# Processing Record 22 of Set 12 | fort nelson
# Processing Record 23 of Set 12 | borskoye
# Processing Record 24 of Set 12 | saurimo
# Processing Record 25 of Set 12 | ha tinh
# Processing Record 26 of Set 12 | bredy
# Processing Record 27 of Set 12 | urdzhar
# City not found. Skipping...
# Processing Record 28 of Set 12 | niono
# Processing Record 29 of Set 12 | belyy yar
# Processing Record 30 of Set 12 | pirgos
# Processing Record 31 of Set 12 | ust-nera
# Processing Record 32 of Set 12 | monteagudo
# Processing Record 33 of Set 12 | chushan
# Processing Record 34 of Set 12 | riviere-au-renard
# Processing Record 35 of Set 12 | cidreira
# Processing Record 36 of Set 12 | matadi
# Processing Record 37 of Set 12 | jinka
# Processing Record 38 of Set 12 | zhezkazgan
# Processing Record 39 of Set 12 | moba
# Processing Record 40 of Set 12 | port hardy
# Processing Record 41 of Set 12 | ashland
# Processing Record 42 of Set 12 | herat
# Processing Record 43 of Set 12 | labuhan
# Processing Record 44 of Set 12 | antofagasta
# Processing Record 45 of Set 12 | hefei
# Processing Record 46 of Set 12 | vila velha
# Processing Record 47 of Set 12 | come
# Processing Record 48 of Set 12 | kentau
# Processing Record 49 of Set 12 | nizhneudinsk
# Processing Record 50 of Set 12 | vila real
# Processing Record 1 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 2 of Set 13 | angoche
# Processing Record 3 of Set 13 | jabiru
# City not found. Skipping...
# Processing Record 4 of Set 13 | stepnogorsk
# Processing Record 5 of Set 13 | tayu
# Processing Record 6 of Set 13 | calabozo
# Processing Record 7 of Set 13 | acurenam
# Processing Record 8 of Set 13 | neiafu
# Processing Record 9 of Set 13 | makakilo city
# Processing Record 10 of Set 13 | tucumcari
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# 561

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_columns_order = ['City','Cloudiness','Country','Date','Humidity', 'Lat', 'Lng', 'Max Temp','Wind Speed']
city_data_df = city_data_df [new_columns_order]
city_data_df.head(10)
# Out:
#              City  Cloudiness Country                 Date  Humidity    Lat  \
# 0       Saskylakh          98      RU  2020-02-16 18:45:21        94  71.92
# 1  Puerto Carreno          40      CO  2020-02-16 18:48:23        34   6.19
# 2           Tiksi         100      RU  2020-02-16 18:48:23        92  71.69
# 3          Sangar         100      RU  2020-02-16 18:48:23        94  63.92
# 4          Faanui          99      PF  2020-02-16 18:48:23        75 -16.48
# 5      Bredasdorp          43      ZA  2020-02-16 18:48:23        56 -34.53
# 6         Fortuna          90      US  2020-02-16 18:48:24        93  40.60
# 7            Ugep          25      NG  2020-02-16 18:48:24        17   5.81
# 8           Lagoa         100      PT  2020-02-16 18:44:07        65  39.05
# 9    Punta Arenas          20      CL  2020-02-16 18:48:24        50 -53.15
#
#       Lng  Max Temp  Wind Speed
# 0  114.08      2.39       10.89
# 1  -67.49     96.80       11.41
# 2  128.87     -2.97        5.26
# 3  127.47    -15.39        8.66
# 4 -151.75     82.22       16.42
# 5   20.04     73.40       20.80
# 6 -124.16     52.00        5.82
# 7    8.08     90.88        4.85
# 8  -27.98     55.02       19.98
# 9  -70.92     53.60       25.28

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
#output_data_file = "weather_data/cities.csv"
#city_data_df=  pd.read_csv(output_data_file)
#city_data_df.head()

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import scipy.stat 
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.  
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()
    print(f"r_value={r_value}")

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n\
                        for Maximum Temperature', 'Max Temp',(10,40))
# Out:
# r_value=-0.8485429483708569

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n\
                        for Maximum Temperature', 'Max Temp',(-50,90))
# Out:
# r_value=0.44152534314881153

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n\
                        for % Humidity', '% Humidity',(40,10))
# Out:
# r_value=0.42789613560687095

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n\
                        for % Humidity', '% Humidity',(-50,15))
# Out:
# r_value=0.32009007435301795

# %%
# Linear regression on the Southern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n\
                        for % Cloudiness', '% Cloudiness',(10,60))
# Out:
# r_value=0.3794675729024455

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n\
                        for % Cloudiness', '% Cloudiness',(-50,60))
# Out:
# r_value=0.15879101005517485

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n\
                        for Wind Speed', 'Wind Speed',(40,35))
# Out:
# r_value=0.13623974189504612

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n\
                        for Wind Speed', 'Wind Speed',(-50,35))
# Out:
# r_value=-0.16753897836783382
