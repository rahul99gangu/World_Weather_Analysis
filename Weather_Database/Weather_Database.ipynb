# %%
# Import the dependencies.
import pandas as pd
import numpy as np
# import the citipy to find the near cities with lat and lot
from citipy import citipy
# import the requests module
import requests
# Import the datetime module from the datetime library.
from datetime import datetime
# Import the time module.
import time
# Import the API key.
from config import weather_api_key

# %%
# use the numpy to generate the uniform random 2000 items
# latutude is -90 and 90 ( equator 0 to the northern end 90 and reversely equator 0 to southern end 90)
lats = np.random.uniform(-90,90,2000)
# longitude is -180 to 180 ( Meridian 0 (GreenSwitch Mean Time (GMT) to Eastern end 180 and to Western 180)
lons = np.random.uniform(-180,180,2000)
# zip function of Python native to create tuple pairs. zip is temporary memory. it will be destroyed after unzip like list
locations = list(zip(lats,lons))

# %%
#Use the citipy.nearest_city to find a city with (lat,lon) tuple
#list conrehensive to populate the list
#need to get the unique city names
cities = [citipy.nearest_city(lat,lon).city_name for lat,lon in locations]
cities = np.unique(cities)
len(cities)
# Out:
# 753

# %%
#use OpenWeather Api to retrieve info
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# function retrieve weather info return a dictionary of the city weather info or NONE
def retrieve_weather_info(index, city_name):
    # query by city name is used &q=city_name
    url_city = f"{url}&q={city_name}"
    city_dict = {}
    print(f"Retrieve {index}::{city_name.upper()} data")
    # open weather is not covered all locations on earth so it may give code 404
    try:
        #if the request successful, convert response data back to json (python dictionary).
        city_weather = requests.get(url_city).json()
        #success code == 200                  
        if city_weather["cod"] == 200:
            city_dict["City"] = city_weather["name"]
            city_dict["Country"] = city_weather["sys"]["country"]
            # Convert the date to ISO standard.
            city_dict["Date"] = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            city_dict["Lat"] = city_weather["coord"]["lat"]
            city_dict["Lng"] = city_weather["coord"]["lon"]
            city_dict["Max Temp"] = city_weather["main"]["temp_max"]
            city_dict["Humidity"] = city_weather["main"]["humidity"]
            city_dict["Cloudiness"] = city_weather["clouds"]["all"]
            city_dict["Wind Speed"] = city_weather["wind"]["speed"]
            city_dict["Current Description"] = city_weather["weather"][0]["description"]
            # return the dict of the city weather info
            return city_dict
        else:
            print(f"{city_name} could not found weather info <Error>")
    except:
       print(f"OpenWeather API were down<Error>")
    return None

# Create an empty list to hold the weather data.
city_data = []
# loop through all cities
for i,city_name in enumerate(cities):
    city_weather_info = retrieve_weather_info(i, city_name)
    if city_weather_info:
        #add the city weather info in the city data list
        city_data.append(city_weather_info)

# Indicate that Data Loading is complete.
print("******Data Retrieval Complete ******")
len(city_data)
# Out:
# Retrieve 0::ABAY data
# Retrieve 1::ABNUB data
# Retrieve 2::ABU SAMRAH data
# Retrieve 3::ABU ZABAD data
# Retrieve 4::ACAPULCO data
# Retrieve 5::ACARAU data
# Retrieve 6::ADA data
# Retrieve 7::ADRAR data
# Retrieve 8::AGADEZ data
# Retrieve 9::AGADIR data
# Retrieve 10::AGROPOLI data
# Retrieve 11::AHIPARA data
# Retrieve 12::AHUIMANU data
# Retrieve 13::AIRAI data
# Retrieve 14::AKLAVIK data
# Retrieve 15::AKSARKA data
# Retrieve 16::AKSU data
# Retrieve 17::ALAMOR data
# Retrieve 18::ALBANY data
# Retrieve 19::ALBURY data
# Retrieve 20::ALDAN data
# Retrieve 21::ALOFI data
# Retrieve 22::ALTA FLORESTA data
# Retrieve 23::ALTAY data
# Retrieve 24::ALYANGULA data
# Retrieve 25::AMAPA data
# Retrieve 26::AMARPUR data
# Retrieve 27::AMBILOBE data
# Retrieve 28::AMBODIFOTOTRA data
# ambodifototra could not found weather info <Error>
# Retrieve 29::AMBON data
# Retrieve 30::AMDERMA data
# amderma could not found weather info <Error>
# Retrieve 31::AMPARAFARAVOLA data
# Retrieve 32::AMPARAI data
# amparai could not found weather info <Error>
# Retrieve 33::ANADYR data
# Retrieve 34::ANAR DARREH data
# anar darreh could not found weather info <Error>
# Retrieve 35::ANCUD data
# Retrieve 36::ANDENES data
# Retrieve 37::ANEHO data
# Retrieve 38::ANTSOHIHY data
# Retrieve 39::ARANDA DE DUERO data
# Retrieve 40::ARENDONK data
# Retrieve 41::ARLIT data
# Retrieve 42::ARMAN data
# Retrieve 43::ARRAIAL DO CABO data
# Retrieve 44::ARVIKA data
# Retrieve 45::ASAU data
# Retrieve 46::ASCENSION data
# Retrieve 47::ASWAN data
# Retrieve 48::ATAMBUA data
# Retrieve 49::ATAR data
# Retrieve 50::ATTAWAPISKAT data
# attawapiskat could not found weather info <Error>
# Retrieve 51::ATUONA data
# Retrieve 52::AUKI data
# Retrieve 53::AVARUA data
# Retrieve 54::AWBARI data
# Retrieve 55::AWJILAH data
# Retrieve 56::AXIM data
# Retrieve 57::AYAGOZ data
# Retrieve 58::AYAN data
# Retrieve 59::AYKHAL data
# Retrieve 60::BABANUSAH data
# babanusah could not found weather info <Error>
# Retrieve 61::BAHERDEN data
# Retrieve 62::BAHIR DAR data
# Retrieve 63::BAIRIKI data
# Retrieve 64::BALABAC data
# Retrieve 65::BALAIPUNGUT data
# Retrieve 66::BALKANABAT data
# Retrieve 67::BAMBOUS VIRIEUX data
# Retrieve 68::BANDARBEYLA data
# Retrieve 69::BANYO data
# Retrieve 70::BAR HARBOR data
# Retrieve 71::BARABINSK data
# Retrieve 72::BARBAR data
# barbar could not found weather info <Error>
# Retrieve 73::BARENTSBURG data
# barentsburg could not found weather info <Error>
# Retrieve 74::BARROW data
# Retrieve 75::BARUUN-URT data
# Retrieve 76::BATKEN data
# Retrieve 77::BATTICALOA data
# Retrieve 78::BAYAN data
# Retrieve 79::BEAUFORT data
# Retrieve 80::BELUSHYA GUBA data
# belushya guba could not found weather info <Error>
# Retrieve 81::BENGKULU data
# Retrieve 82::BENGUELA data
# Retrieve 83::BEREDA data
# Retrieve 84::BERINGOVSKIY data
# Retrieve 85::BERLEVAG data
# Retrieve 86::BETAFO data
# Retrieve 87::BETHEL data
# Retrieve 88::BEYNEU data
# Retrieve 89::BHANVAD data
# Retrieve 90::BHINGA data
# Retrieve 91::BHINMAL data
# Retrieve 92::BIAK data
# Retrieve 93::BICHURA data
# Retrieve 94::BILIBINO data
# Retrieve 95::BILOELA data
# Retrieve 96::BIMA data
# Retrieve 97::BIRJAND data
# Retrieve 98::BISIRA data
# Retrieve 99::BLUFF data
# Retrieve 100::BOCA DO ACRE data
# Retrieve 101::BOENDE data
# Retrieve 102::BOM JESUS data
# Retrieve 103::BOMA data
# Retrieve 104::BONAVISTA data
# Retrieve 105::BONTANG data
# Retrieve 106::BONTHE data
# Retrieve 107::BOROGONTSY data
# Retrieve 108::BOROVOY data
# Retrieve 109::BOWMORE data
# Retrieve 110::BOYOLANGU data
# Retrieve 111::BRAE data
# Retrieve 112::BRAINERD data
# Retrieve 113::BREDASDORP data
# Retrieve 114::BROKEN HILL data
# Retrieve 115::BROOME data
# Retrieve 116::BROWNFIELD data
# Retrieve 117::BUALA data
# Retrieve 118::BUCHANAN data
# Retrieve 119::BUD data
# Retrieve 120::BUIN data
# Retrieve 121::BURAYDAH data
# Retrieve 122::BURNIE data
# Retrieve 123::BURNS LAKE data
# Retrieve 124::BUSSELTON data
# Retrieve 125::BUTARITARI data
# Retrieve 126::CABO SAN LUCAS data
# Retrieve 127::CABUDARE data
# Retrieve 128::CAIRNS data
# Retrieve 129::CALVIA data
# Retrieve 130::CAMACHA data
# Retrieve 131::CAMACUPA data
# Retrieve 132::CAMANA data
# Retrieve 133::CAMIRI data
# Retrieve 134::CAP MALHEUREUX data
# Retrieve 135::CAPE TOWN data
# Retrieve 136::CARMEN data
# Retrieve 137::CARNARVON data
# Retrieve 138::CARNOT data
# Retrieve 139::CARUTAPERA data
# Retrieve 140::CASSILANDIA data
# Retrieve 141::CASTRO data
# Retrieve 142::CAYENNE data
# Retrieve 143::CEDAR CITY data
# Retrieve 144::CHAMPERICO data
# Retrieve 145::CHAMPOTON data
# Retrieve 146::CHARYSHSKOYE data
# Retrieve 147::CHERNYSHEVSKIY data
# Retrieve 148::CHIFENG data
# Retrieve 149::CHIMBOTE data
# Retrieve 150::CHOKURDAKH data
# Retrieve 151::CHUMIKAN data
# Retrieve 152::CHUY data
# Retrieve 153::CIDREIRA data
# Retrieve 154::CLYDE RIVER data
# Retrieve 155::COCKBURN TOWN data
# Retrieve 156::CODRINGTON data
# Retrieve 157::CODY data
# Retrieve 158::COIHAIQUE data
# Retrieve 159::COLAC data
# Retrieve 160::COLLEGE data
# Retrieve 161::COMODORO RIVADAVIA data
# Retrieve 162::CONSTITUCION data
# Retrieve 163::COPIAPO data
# Retrieve 164::COQUIMBO data
# Retrieve 165::CUAMBA data
# Retrieve 166::DALBY data
# Retrieve 167::DALVIK data
# Retrieve 168::DARHAN data
# Retrieve 169::DARU data
# Retrieve 170::DASHITOU data
# Retrieve 171::DEPUTATSKIY data
# Retrieve 172::DIEN BIEN data
# dien bien could not found weather info <Error>
# Retrieve 173::DIGHA data
# Retrieve 174::DIKSON data
# Retrieve 175::DINGLE data
# Retrieve 176::DINGUIRAYE data
# Retrieve 177::DIPKARPAZ data
# dipkarpaz could not found weather info <Error>
# Retrieve 178::DOHA data
# Retrieve 179::DOMONI data
# Retrieve 180::DONGSHENG data
# Retrieve 181::DONJA DUBICA data
# Retrieve 182::DUNAYIVTSI data
# dunayivtsi could not found weather info <Error>
# Retrieve 183::DURBAN data
# Retrieve 184::EAST LONDON data
# Retrieve 185::EMERALD data
# Retrieve 186::ERENHOT data
# Retrieve 187::ESPANOLA data
# Retrieve 188::ESPERANCE data
# Retrieve 189::EVENSK data
# Retrieve 190::EWA BEACH data
# Retrieve 191::EXETER data
# Retrieve 192::EYL data
# Retrieve 193::FAANUI data
# Retrieve 194::FAIRBANKS data
# Retrieve 195::FARANAH data
# Retrieve 196::FAYA data
# Retrieve 197::FLINDERS data
# Retrieve 198::FORMOSO DO ARAGUAIA data
# formoso do araguaia could not found weather info <Error>
# Retrieve 199::FORTUNA data
# Retrieve 200::GAFANHA DA ENCARNACAO data
# Retrieve 201::GALIA data
# Retrieve 202::GALIWINKU data
# galiwinku could not found weather info <Error>
# Retrieve 203::GALLE data
# Retrieve 204::GAMBA data
# Retrieve 205::GARMSAR data
# Retrieve 206::GAT data
# Retrieve 207::GBOKO data
# Retrieve 208::GENERAL PICO data
# Retrieve 209::GENERAL ROCA data
# Retrieve 210::GEORGETOWN data
# Retrieve 211::GERALDTON data
# Retrieve 212::GIMLI data
# Retrieve 213::GINIR data
# Retrieve 214::GIZO data
# Retrieve 215::GOLD COAST data
# Retrieve 216::GORONTALO data
# Retrieve 217::GOURE data
# Retrieve 218::GRAND CENTRE data
# grand centre could not found weather info <Error>
# Retrieve 219::GRAND GAUBE data
# Retrieve 220::GRAND RIVER SOUTH EAST data
# grand river south east could not found weather info <Error>
# Retrieve 221::GRANDE-RIVIERE data
# grande-riviere could not found weather info <Error>
# Retrieve 222::GRANTS data
# Retrieve 223::GRAVDAL data
# Retrieve 224::GREENVILLE data
# Retrieve 225::GRINDAVIK data
# Retrieve 226::GUADUAS data
# Retrieve 227::GUANE data
# Retrieve 228::GUARAPARI data
# Retrieve 229::GUBKINSKIY data
# Retrieve 230::GUERRERO NEGRO data
# Retrieve 231::GUIONG data
# Retrieve 232::HAIBOWAN data
# haibowan could not found weather info <Error>
# Retrieve 233::HAIMEN data
# Retrieve 234::HALF MOON BAY data
# Retrieve 235::HAMBANTOTA data
# Retrieve 236::HAMI data
# Retrieve 237::HAMILTON data
# Retrieve 238::HAMMERFEST data
# Retrieve 239::HANMER SPRINGS data
# Retrieve 240::HARPER data
# Retrieve 241::HASAKI data
# Retrieve 242::HAVELOCK data
# Retrieve 243::HAVOYSUND data
# Retrieve 244::HAY RIVER data
# Retrieve 245::HEMSEDAL data
# Retrieve 246::HENGYANG data
# Retrieve 247::HENTIES BAY data
# Retrieve 248::HERMANUS data
# Retrieve 249::HERVEY BAY data
# Retrieve 250::HIGH ROCK data
# Retrieve 251::HIHIFO data
# hihifo could not found weather info <Error>
# Retrieve 252::HILO data
# Retrieve 253::HITHADHOO data
# Retrieve 254::HOBART data
# Retrieve 255::HOBYO data
# Retrieve 256::HOFN data
# Retrieve 257::HOKITIKA data
# Retrieve 258::HONNINGSVAG data
# Retrieve 259::HOUMA data
# Retrieve 260::HOVD data
# Retrieve 261::HREBINKA data
# Retrieve 262::HRINOVA data
# Retrieve 263::HUALMAY data
# Retrieve 264::HUANUCO data
# Retrieve 265::HUILONG data
# Retrieve 266::HUSAVIK data
# Retrieve 267::IBERIA data
# Retrieve 268::IBRA data
# Retrieve 269::IGACI data
# Retrieve 270::IGARKA data
# Retrieve 271::IJAKI data
# ijaki could not found weather info <Error>
# Retrieve 272::ILHABELA data
# Retrieve 273::ILLAPEL data
# Retrieve 274::ILLOQQORTOORMIUT data
# illoqqortoormiut could not found weather info <Error>
# Retrieve 275::INGHAM data
# Retrieve 276::INUVIK data
# Retrieve 277::INVERELL data
# Retrieve 278::IPAMERI data
# Retrieve 279::IQALUIT data
# Retrieve 280::ISANGEL data
# Retrieve 281::ISETSKOYE data
# Retrieve 282::ISKILIP data
# Retrieve 283::ITAREMA data
# Retrieve 284::ITOMAN data
# Retrieve 285::IVANAVA data
# Retrieve 286::IWANAI data
# Retrieve 287::JACAREACANGA data
# Retrieve 288::JACQUEVILLE data
# Retrieve 289::JAISALMER data
# Retrieve 290::JALU data
# Retrieve 291::JAMESTOWN data
# Retrieve 292::JAQUE data
# Retrieve 293::JATIROTO data
# Retrieve 294::JAUJA data
# Retrieve 295::JIESHI data
# Retrieve 296::JUMLA data
# Retrieve 297::JUNEAU data
# Retrieve 298::KABALE data
# Retrieve 299::KAEO data
# Retrieve 300::KAHULUI data
# Retrieve 301::KAITANGATA data
# Retrieve 302::KALENGWA data
# Retrieve 303::KALMUNAI data
# Retrieve 304::KAMAISHI data
# Retrieve 305::KAMPOT data
# Retrieve 306::KANDRIAN data
# Retrieve 307::KANGAATSIAQ data
# Retrieve 308::KANSK data
# Retrieve 309::KAPAA data
# Retrieve 310::KARAMAY data
# karamay could not found weather info <Error>
# Retrieve 311::KARAMEA data
# karamea could not found weather info <Error>
# Retrieve 312::KARAUL data
# karaul could not found weather info <Error>
# Retrieve 313::KAROI data
# Retrieve 314::KARPATHOS data
# Retrieve 315::KARRATHA data
# Retrieve 316::KASEMPA data
# Retrieve 317::KATANGLI data
# Retrieve 318::KATHERINE data
# Retrieve 319::KATSUURA data
# Retrieve 320::KATTIVAKKAM data
# Retrieve 321::KAUTOKEINO data
# Retrieve 322::KAVARATTI data
# Retrieve 323::KAVIENG data
# Retrieve 324::KAWALU data
# Retrieve 325::KENINGAU data
# Retrieve 326::KEREMA data
# Retrieve 327::KETCHIKAN data
# Retrieve 328::KHANDYGA data
# Retrieve 329::KHARP data
# Retrieve 330::KHASH data
# Retrieve 331::KHATANGA data
# Retrieve 332::KHOMEYN data
# Retrieve 333::KHUZDAR data
# Retrieve 334::KIDAL data
# Retrieve 335::KIFRI data
# Retrieve 336::KIKWIT data
# Retrieve 337::KIRAKIRA data
# Retrieve 338::KISMAYO data
# Retrieve 339::KIUNGA data
# Retrieve 340::KLAKSVIK data
# Retrieve 341::KLOULKLUBED data
# Retrieve 342::KOCH BIHAR data
# Retrieve 343::KODIAK data
# Retrieve 344::KOLOMNA data
# Retrieve 345::KOMSOMOLSKIY data
# Retrieve 346::KORLA data
# Retrieve 347::KORTKEROS data
# Retrieve 348::KOUNGOU data
# Retrieve 349::KRALENDIJK data
# Retrieve 350::KRASNOARMEYSK data
# Retrieve 351::KRUISFONTEIN data
# Retrieve 352::KULACHI data
# Retrieve 353::KUNGURTUG data
# Retrieve 354::KUPANG data
# Retrieve 355::KURUMKAN data
# Retrieve 356::KYRA data
# Retrieve 357::LA MIRADA data
# Retrieve 358::LA PALMA data
# Retrieve 359::LADARIO data
# Retrieve 360::LAGOA data
# Retrieve 361::LAGUNA data
# Retrieve 362::LAKES ENTRANCE data
# Retrieve 363::LAMAR data
# Retrieve 364::LAREDO data
# Retrieve 365::LASA data
# Retrieve 366::LATA data
# Retrieve 367::LAVRENTIYA data
# Retrieve 368::LE MARS data
# Retrieve 369::LEBU data
# Retrieve 370::LENINGRADSKIY data
# Retrieve 371::LEVELLAND data
# Retrieve 372::LIAOYANG data
# Retrieve 373::LIKU data
# Retrieve 374::LINQIONG data
# Retrieve 375::LINXIA data
# Retrieve 376::LLATA data
# Retrieve 377::LODWAR data
# Retrieve 378::LOLUA data
# lolua could not found weather info <Error>
# Retrieve 379::LOMPOC data
# Retrieve 380::LONG BRANCH data
# Retrieve 381::LONGLAC data
# longlac could not found weather info <Error>
# Retrieve 382::LONGYEARBYEN data
# Retrieve 383::LORENGAU data
# Retrieve 384::LOS LLANOS DE ARIDANE data
# Retrieve 385::LOS REYES data
# Retrieve 386::LOUGA data
# Retrieve 387::LOUISBOURG data
# louisbourg could not found weather info <Error>
# Retrieve 388::LUDERITZ data
# Retrieve 389::LUKOVETSKIY data
# Retrieve 390::LYSVA data
# Retrieve 391::LYUBAN data
# Retrieve 392::MACKAY data
# Retrieve 393::MAGHAMA data
# maghama could not found weather info <Error>
# Retrieve 394::MAHAJANGA data
# Retrieve 395::MAHEBOURG data
# Retrieve 396::MAKAKILO CITY data
# Retrieve 397::MAKUSHINO data
# Retrieve 398::MALARTIC data
# Retrieve 399::MALAUT data
# Retrieve 400::MANA data
# Retrieve 401::MANAURE data
# Retrieve 402::MANDALGOVI data
# Retrieve 403::MANDURAH data
# Retrieve 404::MANGGAR data
# Retrieve 405::MANKONO data
# Retrieve 406::MANZANILLO data
# Retrieve 407::MAPIRI data
# Retrieve 408::MAR DEL PLATA data
# Retrieve 409::MARAGOGI data
# Retrieve 410::MARANG data
# Retrieve 411::MARCONA data
# marcona could not found weather info <Error>
# Retrieve 412::MAREEBA data
# Retrieve 413::MARIENTAL data
# Retrieve 414::MARILIA data
# Retrieve 415::MARSA MATRUH data
# Retrieve 416::MARSABIT data
# Retrieve 417::MARSH HARBOUR data
# Retrieve 418::MATAMOROS data
# Retrieve 419::MATARA data
# Retrieve 420::MATAURA data
# Retrieve 421::MAYO data
# Retrieve 422::MAZAGAO data
# Retrieve 423::MECCA data
# Retrieve 424::MERAUKE data
# Retrieve 425::MEULABOH data
# Retrieve 426::MILLINOCKET data
# Retrieve 427::MINGOYO data
# Retrieve 428::MINGYUE data
# Retrieve 429::MIRI data
# Retrieve 430::MITU data
# Retrieve 431::MIZQUE data
# Retrieve 432::MOOSE FACTORY data
# Retrieve 433::MORANT BAY data
# Retrieve 434::MORON data
# Retrieve 435::MOUNT ISA data
# Retrieve 436::MUISNE data
# Retrieve 437::MULI data
# Retrieve 438::MUTOKO data
# Retrieve 439::MUTSAMUDU data
# mutsamudu could not found weather info <Error>
# Retrieve 440::MWANZA data
# Retrieve 441::MWINILUNGA data
# Retrieve 442::MY THO data
# Retrieve 443::MYS SHMIDTA data
# mys shmidta could not found weather info <Error>
# Retrieve 444::NABIRE data
# Retrieve 445::NAJRAN data
# Retrieve 446::NAKHON PHANOM data
# Retrieve 447::NALUT data
# Retrieve 448::NAMBUTALAI data
# Retrieve 449::NAMIBE data
# Retrieve 450::NAMIE data
# Retrieve 451::NANAKULI data
# Retrieve 452::NANLONG data
# Retrieve 453::NANORTALIK data
# Retrieve 454::NARSAQ data
# Retrieve 455::NAZE data
# Retrieve 456::NDIOUM data
# Retrieve 457::NECOCHEA data
# Retrieve 458::NEW NORFOLK data
# Retrieve 459::NEWPORT data
# Retrieve 460::NEZHINSKIY data
# Retrieve 461::NGUKURR data
# ngukurr could not found weather info <Error>
# Retrieve 462::NHAMUNDA data
# Retrieve 463::NIJAR data
# Retrieve 464::NIKOLSKOYE data
# Retrieve 465::NISHIHARA data
# Retrieve 466::NIZHNEVARTOVSK data
# Retrieve 467::NIZHNEYANSK data
# nizhneyansk could not found weather info <Error>
# Retrieve 468::NOKANENG data
# Retrieve 469::NOME data
# Retrieve 470::NORMAN WELLS data
# Retrieve 471::NORSUP data
# Retrieve 472::NORTHAM data
# Retrieve 473::NOVIKOVO data
# Retrieve 474::NYAKAHANGA data
# Retrieve 475::NYLSTROOM data
# nylstroom could not found weather info <Error>
# Retrieve 476::NYURBA data
# Retrieve 477::OGA data
# Retrieve 478::OISTINS data
# Retrieve 479::OKHA data
# Retrieve 480::OKTYABRSKOYE data
# Retrieve 481::OMBOUE data
# Retrieve 482::ONDORHAAN data
# ondorhaan could not found weather info <Error>
# Retrieve 483::OPUWO data
# Retrieve 484::ORANJEMUND data
# Retrieve 485::ORIXIMINA data
# Retrieve 486::ORMARA data
# Retrieve 487::OSMENA data
# Retrieve 488::OSSORA data
# Retrieve 489::OSTERSUND data
# Retrieve 490::OSTROVNOY data
# Retrieve 491::OTTAWA data
# Retrieve 492::OUS data
# Retrieve 493::OVALLE data
# Retrieve 494::OYAMA data
# Retrieve 495::PAAMIUT data
# Retrieve 496::PACIFIC GROVE data
# Retrieve 497::PADANG data
# Retrieve 498::PALABUHANRATU data
# palabuhanratu could not found weather info <Error>
# Retrieve 499::PALANA data
# Retrieve 500::PALMER data
# Retrieve 501::PANDAN data
# Retrieve 502::PANGKALANBUUN data
# Retrieve 503::PANGNIRTUNG data
# Retrieve 504::PANSEMAL data
# Retrieve 505::PARACURU data
# Retrieve 506::PENALVA data
# Retrieve 507::PENZANCE data
# Retrieve 508::PERBAUNGAN data
# Retrieve 509::PETUKHOVO data
# Retrieve 510::PEVEK data
# Retrieve 511::PIMENTEL data
# Retrieve 512::PINCZOW data
# Retrieve 513::PINGZHUANG data
# Retrieve 514::PISCO data
# Retrieve 515::PITSUNDA data
# Retrieve 516::PLACIDO DE CASTRO data
# Retrieve 517::PLAST data
# Retrieve 518::POCHUTLA data
# Retrieve 519::PONTA DO SOL data
# Retrieve 520::PORT ALFRED data
# Retrieve 521::PORT AUGUSTA data
# Retrieve 522::PORT BLAIR data
# Retrieve 523::PORT ELIZABETH data
# Retrieve 524::PORT HARDY data
# Retrieve 525::PORT LINCOLN data
# Retrieve 526::PORT MACQUARIE data
# Retrieve 527::PORT MORESBY data
# Retrieve 528::PORT-CARTIER data
# Retrieve 529::PORTLAND data
# Retrieve 530::PORTO NOVO data
# Retrieve 531::PORTO SANTO data
# Retrieve 532::PORTOBELO data
# Retrieve 533::PRAIA data
# Retrieve 534::PRAIA DA VITORIA data
# Retrieve 535::PRAYA data
# Retrieve 536::PRICE data
# Retrieve 537::PRINCE RUPERT data
# Retrieve 538::PRINCETON data
# Retrieve 539::PROVIDENIYA data
# Retrieve 540::PUERTO AYORA data
# Retrieve 541::PUERTO BAQUERIZO MORENO data
# Retrieve 542::PUERTO MONTT data
# Retrieve 543::PUERTO QUIJARRO data
# Retrieve 544::PULLMAN data
# Retrieve 545::PUNTA ARENAS data
# Retrieve 546::QAANAAQ data
# Retrieve 547::QAQORTOQ data
# Retrieve 548::QASIGIANNGUIT data
# Retrieve 549::QAX data
# Retrieve 550::QINGDAO data
# Retrieve 551::QUATRE COCOS data
# Retrieve 552::QUELIMANE data
# Retrieve 553::RAICHUR data
# Retrieve 554::RANTOUL data
# Retrieve 555::RAUDEBERG data
# Retrieve 556::RAWSON data
# Retrieve 557::REINOSA data
# Retrieve 558::RIBEIRA GRANDE data
# Retrieve 559::RICHARDS BAY data
# Retrieve 560::RIKITEA data
# Retrieve 561::RIO CLARO data
# Retrieve 562::RIO GALLEGOS data
# Retrieve 563::ROAD TOWN data
# Retrieve 564::ROEBOURNE data
# Retrieve 565::ROLIM DE MOURA data
# rolim de moura could not found weather info <Error>
# Retrieve 566::RUNGATA data
# rungata could not found weather info <Error>
# Retrieve 567::RUSSELL data
# Retrieve 568::SABHA data
# Retrieve 569::SADRI data
# Retrieve 570::SAHRAK data
# sahrak could not found weather info <Error>
# Retrieve 571::SAINT ANTHONY data
# Retrieve 572::SAINT GEORGE data
# Retrieve 573::SAINT-DENIS data
# Retrieve 574::SAINT-JOSEPH data
# Retrieve 575::SAINT-PHILIPPE data
# Retrieve 576::SAINTE-MARIE data
# Retrieve 577::SAKAKAH data
# Retrieve 578::SALALAH data
# Retrieve 579::SALDANHA data
# Retrieve 580::SALEAULA data
# saleaula could not found weather info <Error>
# Retrieve 581::SALEKHARD data
# Retrieve 582::SALINAS data
# Retrieve 583::SAMARAI data
# Retrieve 584::SAMPIT data
# Retrieve 585::SAMUSU data
# samusu could not found weather info <Error>
# Retrieve 586::SAN ANDRES data
# Retrieve 587::SAN CARLOS DE BARILOCHE data
# Retrieve 588::SAN CRISTOBAL data
# Retrieve 589::SAN ISIDRO data
# Retrieve 590::SAN JERONIMO data
# Retrieve 591::SAN JOSE data
# Retrieve 592::SAN JUAN data
# Retrieve 593::SAN LORENZO data
# Retrieve 594::SAN PATRICIO data
# Retrieve 595::SAN POLICARPO data
# Retrieve 596::SAN QUINTIN data
# Retrieve 597::SAN RAMON data
# Retrieve 598::SAN VICENTE data
# Retrieve 599::SANTA BARBARA data
# Retrieve 600::SANTAREM data
# Retrieve 601::SAO JOAO data
# Retrieve 602::SAO JOAO DA BARRA data
# Retrieve 603::SAO MIGUEL DO TAPUIO data
# Retrieve 604::SARYG-SEP data
# Retrieve 605::SASKYLAKH data
# Retrieve 606::SATAUA data
# sataua could not found weather info <Error>
# Retrieve 607::SAVANNAH BIGHT data
# Retrieve 608::SAWAKIN data
# Retrieve 609::SECHURA data
# Retrieve 610::SENTYABRSKIY data
# sentyabrskiy could not found weather info <Error>
# Retrieve 611::SEREBRYANSK data
# Retrieve 612::SEVERO-KURILSK data
# Retrieve 613::SEVERO-YENISEYSKIY data
# Retrieve 614::SHACHE data
# Retrieve 615::SHAHDADKOT data
# Retrieve 616::SHELBURNE data
# Retrieve 617::SHELBYVILLE data
# Retrieve 618::SHETPE data
# Retrieve 619::SHIELI data
# Retrieve 620::SHIMODA data
# Retrieve 621::SHINGU data
# Retrieve 622::SHIZUNAI data
# Retrieve 623::SHUNYI data
# Retrieve 624::SIERPC data
# Retrieve 625::SINNAMARY data
# Retrieve 626::SIOCON data
# Retrieve 627::SISIMIUT data
# Retrieve 628::SITKA data
# Retrieve 629::SKAGASTROND data
# skagastrond could not found weather info <Error>
# Retrieve 630::SNYDER data
# Retrieve 631::SOBOLEVO data
# Retrieve 632::SOLEDADE data
# Retrieve 633::SOLNECHNYY data
# Retrieve 634::SOLSVIK data
# solsvik could not found weather info <Error>
# Retrieve 635::SOLTVADKERT data
# Retrieve 636::SORATA data
# Retrieve 637::SORLAND data
# Retrieve 638::SORONG data
# Retrieve 639::SOSNOVO-OZERSKOYE data
# Retrieve 640::SOUILLAC data
# Retrieve 641::SOYO data
# Retrieve 642::SPRINGBOK data
# Retrieve 643::SREDNEKOLYMSK data
# Retrieve 644::SRIVARDHAN data
# Retrieve 645::STARYY BISER data
# staryy biser could not found weather info <Error>
# Retrieve 646::SUR data
# Retrieve 647::SUZU data
# suzu could not found weather info <Error>
# Retrieve 648::SVETLOGORSK data
# Retrieve 649::SWIFT CURRENT data
# Retrieve 650::TABIAUEA data
# tabiauea could not found weather info <Error>
# Retrieve 651::TABOU data
# Retrieve 652::TABUK data
# Retrieve 653::TACNA data
# Retrieve 654::TADINE data
# Retrieve 655::TAGUSAO data
# Retrieve 656::TAKORADI data
# Retrieve 657::TALNAKH data
# Retrieve 658::TANOUT data
# Retrieve 659::TAOLANARO data
# taolanaro could not found weather info <Error>
# Retrieve 660::TAOUDENNI data
# Retrieve 661::TASIILAQ data
# Retrieve 662::TAWANG data
# Retrieve 663::TAZMALT data
# Retrieve 664::TAZOVSKIY data
# Retrieve 665::TE ANAU data
# Retrieve 666::TEGUISE data
# Retrieve 667::TEVAITOA data
# Retrieve 668::TEVRIZ data
# Retrieve 669::TEYA data
# Retrieve 670::THOMPSON data
# Retrieve 671::TIDORE data
# tidore could not found weather info <Error>
# Retrieve 672::TIELI data
# Retrieve 673::TIELING data
# Retrieve 674::TIGIL data
# Retrieve 675::TIKSI data
# Retrieve 676::TILICHIKI data
# Retrieve 677::TIRUVOTTIYUR data
# tiruvottiyur could not found weather info <Error>
# Retrieve 678::TKVARCHELI data
# tkvarcheli could not found weather info <Error>
# Retrieve 679::TOLIARY data
# toliary could not found weather info <Error>
# Retrieve 680::TORBAY data
# Retrieve 681::TORZHOK data
# Retrieve 682::TRAIRI data
# Retrieve 683::TRAT data
# Retrieve 684::TRELEW data
# Retrieve 685::TRINDADE data
# Retrieve 686::TSARATANANA data
# Retrieve 687::TSIHOMBE data
# tsihombe could not found weather info <Error>
# Retrieve 688::TUAL data
# Retrieve 689::TUATAPERE data
# Retrieve 690::TUCUMAN data
# Retrieve 691::TUKTOYAKTUK data
# Retrieve 692::TULUN data
# Retrieve 693::TUMANNYY data
# tumannyy could not found weather info <Error>
# Retrieve 694::TURUKHANSK data
# Retrieve 695::UCLUELET data
# Retrieve 696::ULLADULLA data
# Retrieve 697::ULU-TELYAK data
# Retrieve 698::UMBA data
# Retrieve 699::UMZIMVUBU data
# umzimvubu could not found weather info <Error>
# Retrieve 700::UPERNAVIK data
# Retrieve 701::URUCARA data
# Retrieve 702::USHUAIA data
# Retrieve 703::UZUMLU data
# uzumlu could not found weather info <Error>
# Retrieve 704::VAINI data
# Retrieve 705::VAITUPU data
# vaitupu could not found weather info <Error>
# Retrieve 706::VAN data
# Retrieve 707::VANIMO data
# Retrieve 708::VAO data
# Retrieve 709::VARDO data
# Retrieve 710::VERKHNYAYA INTA data
# Retrieve 711::VERKHNYAYA MAKSAKOVKA data
# Retrieve 712::VERKHOYANSK data
# Retrieve 713::VESTMANNA data
# Retrieve 714::VESTMANNAEYJAR data
# Retrieve 715::VICTORIA data
# Retrieve 716::VIEDMA data
# Retrieve 717::VIKESA data
# Retrieve 718::VIKULOVO data
# Retrieve 719::VILA data
# Retrieve 720::VILA FRANCA DO CAMPO data
# Retrieve 721::VILA VELHA data
# Retrieve 722::VOSTOK data
# Retrieve 723::WAGAR data
# Retrieve 724::WAINGAPU data
# Retrieve 725::WAIPAWA data
# Retrieve 726::WAKKANAI data
# Retrieve 727::WARQLA data
# warqla could not found weather info <Error>
# Retrieve 728::WARWICK data
# Retrieve 729::WATSA data
# Retrieve 730::WHITEHAVEN data
# Retrieve 731::WHITEHORSE data
# Retrieve 732::WLADYSLAWOWO data
# Retrieve 733::WUKARI data
# Retrieve 734::WYNDHAM data
# Retrieve 735::XAPURI data
# Retrieve 736::XIAOWEIZHAI data
# Retrieve 737::XUDDUR data
# Retrieve 738::YELLOWKNIFE data
# Retrieve 739::YENISEYSK data
# Retrieve 740::YEPPOON data
# Retrieve 741::YERBOGACHEN data
# Retrieve 742::YIROL data
# yirol could not found weather info <Error>
# Retrieve 743::YULARA data
# Retrieve 744::YUMEN data
# Retrieve 745::YURIMAGUAS data
# Retrieve 746::ZABOL data
# Retrieve 747::ZELENOBORSK data
# Retrieve 748::ZHELEZNODOROZHNYY data
# Retrieve 749::ZHIGANSK data
# Retrieve 750::ZLOBIN data
# Retrieve 751::ZUWARAH data
# Retrieve 752::ZYRYANKA data
# ******Data Retrieval Complete ******
# 693

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City Country                 Date      Lat       Lng  \
# 0                Abay      KZ  2021-06-06 23:05:08  49.6311   72.8539
# 1               Abnūb      EG  2021-06-06 23:05:08  27.2696   31.1511
# 2          Abu Samrah      SY  2021-06-06 23:05:09  35.3029   37.1841
# 3           Abū Zabad      SD  2021-06-06 23:09:07  12.3500   29.2500
# 4  Acapulco de Juárez      MX  2021-06-06 23:14:00  16.8634  -99.8901
# 5              Acaraú      BR  2021-06-06 23:14:00  -2.8856  -40.1200
# 6                 Ada      US  2021-06-06 23:14:00  43.4166 -116.1262
# 7               Adrar      MR  2021-06-06 23:05:10  20.5022  -10.0711
# 8              Agadez      NE  2021-06-06 23:14:01  19.7500   10.2500
# 9          Santa Cruz      MA  2021-06-06 23:11:10  30.4202   -9.5982
#
#    Max Temp  Humidity  Cloudiness  Wind Speed Current Description
# 0     39.58        48          31        8.19    scattered clouds
# 1     75.54        36          18       17.94          few clouds
# 2     66.25        43           0        6.78           clear sky
# 3     82.69        50          81       12.75       broken clouds
# 4     89.42        70          75       10.74       broken clouds
# 5     77.83        86          30        9.37    scattered clouds
# 6     76.35        21           1       15.01           clear sky
# 7     95.04        13          71       18.70       broken clouds
# 8     90.30        10         100        9.35     overcast clouds
# 9     66.65        86          49        7.58    scattered clouds

# %% [markdown]
# ***Answer this question using Pandas methods: How many cities have recorded rainfall or snow?***

# %%
# Export the City_Data into a CSV without index.
city_data_df.to_csv("weather_data/WeatherPy_challenge.csv",index=False)
